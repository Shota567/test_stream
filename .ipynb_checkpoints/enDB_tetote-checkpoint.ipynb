# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\matsuno\anaconda3\lib\site-packages (4.2.0)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\matsuno\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio~=0.17 in c:\users\matsuno\anaconda3\lib\site-packages (from selenium) (0.20.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\matsuno\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: sortedcontainers in c:\users\matsuno\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\matsuno\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sniffio in c:\users\matsuno\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\matsuno\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: outcome in c:\users\matsuno\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\matsuno\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\matsuno\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: pycparser in c:\users\matsuno\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\matsuno\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\matsuno\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\matsuno\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.7)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\matsuno\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: certifi in c:\users\matsuno\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\matsuno\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\matsuno\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
from selenium import webdriver

import time

import pandas as pd

from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

import re

import numpy as np

# %%
IIDA = ['PMC010' , 'PPP0224']

HEAD_HUNTER_all = [IIDA]

url_login = 'https://mid-tenshoku.com/company_login/login/?PK=DB1298'

# %%
i = 0
HEAD_HUNTER = HEAD_HUNTER_all[i]

# %%
browser = webdriver.Chrome(executable_path = 'C:/Users/matsuno/Downloads/MyPandas/chromedriver.exe')
browser.implicitly_wait(1)
browser.get(url_login)
time.sleep(1)
print("ログインページに開きました")
# Out:
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\3865556714.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path = 'C:/Users/matsuno/Downloads/MyPandas/chromedriver.exe')
# ログインページに開きました

# %%
element = browser.find_element_by_name('accLoginID')
element.clear()
element.send_keys(HEAD_HUNTER[0])

element = browser.find_element_by_name('accLoginPW')
element.clear()
element.send_keys(HEAD_HUNTER[1])
print("情報を入力しました")

browser_from = browser.find_element_by_xpath('/html/body/section/section[2]/div/form/div/span/button')
time.sleep(1)
browser_from.click()
time.sleep(1)
print("情報を入力してログインボタンを押しました")
# Out:
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\839271715.py:1: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   element = browser.find_element_by_name('accLoginID')
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\839271715.py:5: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   element = browser.find_element_by_name('accLoginPW')
# 情報を入力しました
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\839271715.py:10: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/section/section[2]/div/form/div/span/button')
# 情報を入力してログインボタンを押しました

# %%
j = 0

for e in range(77,81):
    
    browser.get('https://mid-tenshoku.com/company/scout_emp/?PK=DB1298')
    time.sleep(1)
    print("エンDBに移動")
    
    browser_from = browser.find_element_by_xpath('/html/body/section/div[3]/section[1]/form/div[1]/div[1]/div[2]/select')
    browser_from.click()
    time.sleep(1)
    print("スカウト条件ボタンを押しました")

    browser_from = browser.find_element_by_xpath('/html/body/section/div[3]/section[1]/form/div[1]/div[1]/div[2]/select/option[' + str(e) + ']')
    browser_from.click()
    time.sleep(5)

    browser_from = browser.find_element_by_xpath('/html/body/section/div[2]/div/div[2]/ul[1]/li[1]/span[2]')
    print(browser_from.text + "を送信します")

    browser_from = browser.find_element_by_xpath('/html/body/section/section/div/div[1]/span/span[1]')
    print("全" + browser_from.text + "件")

    kensuu = int(browser_from.text)
    if kensuu > 200:
        kensuu = 200

    for i in range(1,kensuu + 2):

        try:
            browser_from = browser.find_element_by_xpath('/html/body/section/section/div/div[2]/div[' + str(i) + ']/div[1]/div[1]/div[1]/div[3]')
        except NoSuchElementException:
            try:
                browser_from = browser.find_element_by_xpath('/html/body/section/section/div/div[2]/div[' + str(i) + ']/div[1]/div/div[1]/div[3]')
            except NoSuchElementException:
                print("求職者でない箇所")
                continue

        hantei = browser_from.text.splitlines()
        print(str(i) + "番目")

        if hantei[0] == "女性":
            if 20 <= int(re.sub(r"\D", "", hantei[1].split('歳')[0])) <= 34:
                print(hantei)

                browser_from.click()
                time.sleep(3)
                print("求職者詳細へ移動")

                browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[1]/select/option[2]')
                browser_from.click()
                time.sleep(1)
                print(browser_from.text + "　スカウトを選択")

                if not "テトテ" in browser_from.text:
                    break

                element = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[6]/div[1]/input')
                if not element.is_selected():
                    element.find_element_by_xpath("following-sibling::label").click()
                time.sleep(1)
                print("リマインドを選択")

                time.sleep(1)
                browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[6]/div[2]/select/option[2]')
                browser_from.click()
                print(browser_from.text + "　再送スカウトを選択")

                if not "テトテ" in browser_from.text:
                    break

                browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[6]/div[5]/div[1]/label')
                browser_from.click()
                print("再送信を選択")

                browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[6]/div[5]/div[1]/label/select/option[10]')
                browser_from.click()
                print("再送信日を選択")

                time.sleep(1)
                browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[8]/div/a[3]')
                browser_from.click()
                time.sleep(1)
                browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[8]/div/div/div[2]/a[1]')
                browser_from.click()
                time.sleep(1)

                j += 1
                print(str(j) + "件目のスカウト送信")

                time.sleep(1)
                browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/a')
                browser_from.click()
                print("求職者詳細を閉じる")
                time.sleep(1)

            else:
                print("年齢NG")
        else:
            print("性別NG")
# Out:
# エンDBに移動
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:9: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/section/div[3]/section[1]/form/div[1]/div[1]/div[2]/select')
# スカウト条件ボタンを押しました
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:14: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/section/div[3]/section[1]/form/div[1]/div[1]/div[2]/select/option[' + str(e) + ']')
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:18: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/section/div[2]/div/div[2]/ul[1]/li[1]/span[2]')
# テトテ1を送信します
# 全47件
# 1番目
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:21: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/section/section/div/div[1]/span/span[1]')
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:31: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/section/section/div/div[2]/div[' + str(i) + ']/div[1]/div[1]/div[1]/div[3]')
# ['女性', '22歳 / 東京都']
# 求職者詳細へ移動
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:50: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[1]/select/option[2]')
# 3テトテ 20-34歳　スカウトを選択
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:58: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   element = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[6]/div[1]/input')
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:60: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   element.find_element_by_xpath("following-sibling::label").click()
# リマインドを選択
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:65: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[6]/div[2]/select/option[2]')
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[6]/div[5]/div[1]/label')
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:76: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[6]/div[5]/div[1]/label/select/option[3]')
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:81: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[8]/div/a[3]')
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:84: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div[4]/div/div/div/div/div[2]/form/div[8]/div/div/div[2]/a[1]')
# 1件目のスカウト送信
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:92: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/a')
# 求職者詳細を閉じる
# 2番目
# ['女性', '23歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 2件目のスカウト送信
# 求職者詳細を閉じる
# 3番目
# ['女性', '21歳 / 神奈川県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 3件目のスカウト送信
# 求職者詳細を閉じる
# 4番目
# ['女性', '26歳 / 神奈川県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 4件目のスカウト送信
# 求職者詳細を閉じる
# 5番目
# ['女性', '25歳 / 千葉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 5件目のスカウト送信
# 求職者詳細を閉じる
# 6番目
# 性別NG
# 7番目
# 性別NG
# 8番目
# 性別NG
# 9番目
# 性別NG
# 10番目
# 性別NG
# 11番目
# 年齢NG
# 12番目
# 性別NG
# 13番目
# 性別NG
# 14番目
# 性別NG
# 15番目
# 性別NG
# 16番目
# 性別NG
# 17番目
# 性別NG
# 18番目
# 性別NG
# 19番目
# ['女性', '27歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 6件目のスカウト送信
# 求職者詳細を閉じる
# 20番目
# 性別NG
# 21番目
# 性別NG
# 22番目
# 性別NG
# 23番目
# 性別NG
# 24番目
# 性別NG
# 25番目
# 性別NG
# 26番目
# 性別NG
# 27番目
# 性別NG
# 28番目
# 性別NG
# 29番目
# 性別NG
# 30番目
# 性別NG
# 31番目
# 性別NG
# 32番目
# 性別NG
# 33番目
# 性別NG
# 34番目
# 性別NG
# 35番目
# 性別NG
# 36番目
# ['女性', '25歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 7件目のスカウト送信
# 求職者詳細を閉じる
# 37番目
# 性別NG
# 38番目
# ['女性', '29歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 8件目のスカウト送信
# 求職者詳細を閉じる
# 39番目
# 性別NG
# 40番目
# 年齢NG
# 41番目
# ['女性', '23歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 9件目のスカウト送信
# 求職者詳細を閉じる
# 42番目
# 性別NG
# 43番目
# ['女性', '28歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 10件目のスカウト送信
# 求職者詳細を閉じる
# 44番目
# 性別NG
# 45番目
# 性別NG
# 46番目
# 性別NG
# 47番目
# 性別NG
# C:\Users\matsuno\AppData\Local\Temp\ipykernel_9456\2071946076.py:34: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   browser_from = browser.find_element_by_xpath('/html/body/section/section/div/div[2]/div[' + str(i) + ']/div[1]/div/div[1]/div[3]')
# 求職者でない箇所
# エンDBに移動
# スカウト条件ボタンを押しました
# テトテ2を送信します
# 全14件
# 1番目
# 性別NG
# 2番目
# 性別NG
# 3番目
# 性別NG
# 4番目
# 性別NG
# 5番目
# 性別NG
# 求職者でない箇所
# 7番目
# ['女性', '34歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 11件目のスカウト送信
# 求職者詳細を閉じる
# 8番目
# 性別NG
# 9番目
# 性別NG
# 10番目
# 性別NG
# 11番目
# 性別NG
# 12番目
# 年齢NG
# 13番目
# 性別NG
# 14番目
# 性別NG
# 15番目
# ['女性', '26歳 / 神奈川県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 12件目のスカウト送信
# 求職者詳細を閉じる
# エンDBに移動
# スカウト条件ボタンを押しました
# テトテ3を送信します
# 全36件
# 1番目
# 性別NG
# 2番目
# 性別NG
# 3番目
# 性別NG
# 4番目
# 性別NG
# 5番目
# 年齢NG
# 6番目
# 性別NG
# 7番目
# 性別NG
# 8番目
# 年齢NG
# 9番目
# 性別NG
# 10番目
# 性別NG
# 11番目
# 性別NG
# 12番目
# 性別NG
# 13番目
# 性別NG
# 14番目
# 性別NG
# 15番目
# 性別NG
# 16番目
# 年齢NG
# 17番目
# 性別NG
# 18番目
# 性別NG
# 19番目
# 性別NG
# 20番目
# 性別NG
# 21番目
# 性別NG
# 22番目
# 性別NG
# 23番目
# 性別NG
# 24番目
# 性別NG
# 25番目
# 性別NG
# 26番目
# 性別NG
# 27番目
# 性別NG
# 28番目
# 性別NG
# 29番目
# 年齢NG
# 30番目
# ['女性', '24歳 / 埼玉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 13件目のスカウト送信
# 求職者詳細を閉じる
# 31番目
# 性別NG
# 32番目
# 性別NG
# 33番目
# 性別NG
# 34番目
# 年齢NG
# 35番目
# 性別NG
# 36番目
# 性別NG
# 求職者でない箇所
# エンDBに移動
# スカウト条件ボタンを押しました
# テトテ4を送信します
# 全148件
# 1番目
# ['女性', '25歳 / 神奈川県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 14件目のスカウト送信
# 求職者詳細を閉じる
# 2番目
# ['女性', '28歳 / 神奈川県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 15件目のスカウト送信
# 求職者詳細を閉じる
# 3番目
# ['女性', '21歳 / 千葉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 16件目のスカウト送信
# 求職者詳細を閉じる
# 4番目
# ['女性', '32歳 / 千葉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 17件目のスカウト送信
# 求職者詳細を閉じる
# 5番目
# ['女性', '24歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 18件目のスカウト送信
# 求職者詳細を閉じる
# 6番目
# ['女性', '27歳 / 千葉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 19件目のスカウト送信
# 求職者詳細を閉じる
# 7番目
# ['女性', '29歳 / 埼玉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 20件目のスカウト送信
# 求職者詳細を閉じる
# 8番目
# ['女性', '25歳 / 神奈川県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 21件目のスカウト送信
# 求職者詳細を閉じる
# 9番目
# ['女性', '30歳 / 神奈川県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 22件目のスカウト送信
# 求職者詳細を閉じる
# 10番目
# ['女性', '22歳 / 埼玉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 23件目のスカウト送信
# 求職者詳細を閉じる
# 11番目
# 性別NG
# 12番目
# ['女性', '28歳 / 埼玉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 24件目のスカウト送信
# 求職者詳細を閉じる
# 13番目
# ['女性', '23歳 / 神奈川県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 25件目のスカウト送信
# 求職者詳細を閉じる
# 14番目
# 性別NG
# 15番目
# 性別NG
# 16番目
# 性別NG
# 17番目
# 性別NG
# 18番目
# 性別NG
# 19番目
# 性別NG
# 20番目
# 性別NG
# 21番目
# 性別NG
# 22番目
# 性別NG
# 23番目
# 性別NG
# 24番目
# 性別NG
# 25番目
# 性別NG
# 26番目
# 年齢NG
# 27番目
# 性別NG
# 28番目
# 性別NG
# 29番目
# 性別NG
# 30番目
# 性別NG
# 31番目
# 性別NG
# 32番目
# 性別NG
# 33番目
# 性別NG
# 34番目
# 性別NG
# 35番目
# 性別NG
# 36番目
# 性別NG
# 37番目
# 性別NG
# 38番目
# 性別NG
# 39番目
# 性別NG
# 40番目
# ['女性', '24歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 26件目のスカウト送信
# 求職者詳細を閉じる
# 41番目
# 性別NG
# 42番目
# 性別NG
# 43番目
# 性別NG
# 44番目
# 性別NG
# 45番目
# 性別NG
# 46番目
# 性別NG
# 47番目
# 性別NG
# 48番目
# 性別NG
# 49番目
# 性別NG
# 50番目
# 性別NG
# 51番目
# ['女性', '24歳 / 埼玉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 27件目のスカウト送信
# 求職者詳細を閉じる
# 52番目
# 性別NG
# 53番目
# 性別NG
# 54番目
# 性別NG
# 55番目
# 性別NG
# 56番目
# 性別NG
# 57番目
# 性別NG
# 58番目
# 性別NG
# 59番目
# 性別NG
# 60番目
# 性別NG
# 61番目
# 性別NG
# 62番目
# 性別NG
# 63番目
# 性別NG
# 64番目
# 性別NG
# 65番目
# ['女性', '30歳 / 神奈川県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 28件目のスカウト送信
# 求職者詳細を閉じる
# 66番目
# 性別NG
# 67番目
# 性別NG
# 68番目
# 性別NG
# 69番目
# 性別NG
# 70番目
# 性別NG
# 71番目
# ['女性', '32歳 / 神奈川県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 29件目のスカウト送信
# 求職者詳細を閉じる
# 72番目
# 性別NG
# 73番目
# ['女性', '25歳 / 神奈川県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 30件目のスカウト送信
# 求職者詳細を閉じる
# 74番目
# ['女性', '26歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 31件目のスカウト送信
# 求職者詳細を閉じる
# 75番目
# ['女性', '24歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 32件目のスカウト送信
# 求職者詳細を閉じる
# 76番目
# 性別NG
# 77番目
# 性別NG
# 78番目
# 性別NG
# 79番目
# ['女性', '24歳 / 千葉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 33件目のスカウト送信
# 求職者詳細を閉じる
# 80番目
# 性別NG
# 81番目
# 性別NG
# 82番目
# 性別NG
# 83番目
# 性別NG
# 84番目
# 性別NG
# 85番目
# ['女性', '26歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 34件目のスカウト送信
# 求職者詳細を閉じる
# 86番目
# 性別NG
# 87番目
# 性別NG
# 88番目
# 性別NG
# 89番目
# 性別NG
# 90番目
# 性別NG
# 91番目
# 性別NG
# 92番目
# 性別NG
# 93番目
# 性別NG
# 94番目
# 性別NG
# 95番目
# 性別NG
# 96番目
# 性別NG
# 97番目
# 性別NG
# 98番目
# 性別NG
# 99番目
# 性別NG
# 100番目
# 性別NG
# 101番目
# 性別NG
# 102番目
# 性別NG
# 103番目
# ['女性', '31歳 / 東京都']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 35件目のスカウト送信
# 求職者詳細を閉じる
# 104番目
# 性別NG
# 105番目
# 性別NG
# 106番目
# 性別NG
# 107番目
# 性別NG
# 108番目
# 性別NG
# 109番目
# 性別NG
# 110番目
# 性別NG
# 111番目
# ['女性', '25歳 / 千葉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 36件目のスカウト送信
# 求職者詳細を閉じる
# 112番目
# 性別NG
# 113番目
# 性別NG
# 114番目
# 性別NG
# 115番目
# 性別NG
# 116番目
# 性別NG
# 117番目
# 性別NG
# 118番目
# ['女性', '25歳 / 埼玉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 37件目のスカウト送信
# 求職者詳細を閉じる
# 119番目
# 性別NG
# 120番目
# 性別NG
# 121番目
# 性別NG
# 122番目
# 性別NG
# 123番目
# 性別NG
# 124番目
# 性別NG
# 125番目
# 性別NG
# 126番目
# ['女性', '25歳 / 千葉県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 38件目のスカウト送信
# 求職者詳細を閉じる
# 127番目
# 性別NG
# 128番目
# 性別NG
# 129番目
# 性別NG
# 130番目
# 性別NG
# 131番目
# 性別NG
# 132番目
# 性別NG
# 133番目
# 性別NG
# 134番目
# 性別NG
# 135番目
# 性別NG
# 136番目
# 性別NG
# 137番目
# 年齢NG
# 138番目
# 性別NG
# 139番目
# 性別NG
# 140番目
# 性別NG
# 141番目
# ['女性', '30歳 / 神奈川県']
# 求職者詳細へ移動
# 3テトテ 20-34歳　スカウトを選択
# リマインドを選択
# 3テトテ 20-34歳　再送スカウトを選択
# 再送信を選択
# 再送信日を選択
# 39件目のスカウト送信
# 求職者詳細を閉じる
# 142番目
# 性別NG
# 143番目
# 性別NG
# 144番目
# 性別NG
# 145番目
# 性別NG
# 146番目
# 性別NG
# 147番目
# 性別NG
# 148番目
# 性別NG
# 求職者でない箇所
