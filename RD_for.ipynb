# %%
# !pip install selenium

# %%
from selenium import webdriver

import time

import pandas as pd

from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

from selenium.common.exceptions import NoSuchElementException

from bs4 import BeautifulSoup
import requests

import re

import numpy as np

# %%
DAY = '2023/02/20'

GOTO = ['goto@assemblage.co.jp' , 'Goto10231023']
#OKAMOTO = ['y-okamoto@pmc-g.jp' , 'yutaka-Okamoto581214']
IIDA = ['iida@pmc-g.jp' , 'pmcpmcpmc1207']
TAMURA = ['tamura@assemblage.asia' , 'tamura20220301']
KAWATSURA = ['kawatsura@assemblage.asia' , 'Yurakutyo2022']
RIKITAKE = ['rikitake@pmc-g.jp' , 'rikitake1020']
SUZUKI = ['suzuki_a@assemblage.asia' , 'Yurakutyo2022']
NOBUSHIMA = ['nobushima@assemblage.co.jp' , 'Yurakutyo2022']
MORI = ['mori@pmc-g.jp' , 'yumi1201rds']

HEAD_HUNTER_all = [GOTO , IIDA , TAMURA , KAWATSURA , RIKITAKE , SUZUKI , NOBUSHIMA , MORI]

url_login = 'https://agt.directscout.recruit.co.jp/agent/login'

# %%
df_count = pd.DataFrame(columns=['コンサルタント','send_tittle','number'])
df_monitoring_count = pd.DataFrame(columns=['コンサルタント','送信全件','通常スカウト''一球入魂','fithunter','自動再送','リマチャン','「再送除く」','返信数'])

# %%
for i in range(0,8):

    HEAD_HUNTER = HEAD_HUNTER_all[i]
    
    if i == 0:
        scout_title = ["","組織コンサル","脱M&A仲介","コーポレート","医療法人の","医療法人経営支援","【人事企画】～働きがい向上に","採用から","コストコンサル","既存事業、新規事業共に加速できる","不動産売買事業を展開する","経営企画部門の管理職候補の募集】","社内ITサポート業務","【講師業務】","×ICT","経理/財務","人事担当募集","財務課長","戦略企画室","商品戦略","財務経理部","法務総務部","施設運営マネージャー募集","福祉法人の","インテリア・ファッション","想いを実現できる人","転職活動の"]
    #elif i == 1:
        #scout_title = ["","組織コンサル","医療法人の","マネージャー候補","既存事業、新規事業共に加速できる","不動産売買事業を展開する","不動産売買事業を展開する企業）の経営企画ポジション","×ICT","働く人の","M&Aコンサルタントの","人材事業と新規事業を一緒","レジュメを拝見させて頂きました","ご連絡させて","転職活動の"]
    elif i == 1:
        scout_title = ["","【管理職候補/医療法人の運営マネージャー（業界未経験者7割入社）】／年休122日／入社後すぐ有給付与","【HRBP】成長する医療業界をHR領域から支えていく人事企画（東証プライム上場グループ/社員数400名/設立9年）"]
        #scout_title = ["","組織コンサル","医療法人の","管理職候補","コーポレート","コーポレート部門で企画","コーポレート部門で経理","コーポレート部門で法務","コーポレート部門で人事","人事担当募集","ご面談の","外資金融","転職活動の"]
        continue     
    elif i == 2:
        continue
        scout_title = ["","組織コンサル","医療法人の","管理職候補","コーポレート","コーポレート部門で企画","コーポレート部門で経理","コーポレート部門で法務","コーポレート部門で人事","介護施設の施設長","の人事部門","既存事業、新規事業共に加速できる","×ICT","経理/財務","財務課長候補","法務責任者","ご面談の","その後の"]
    elif i == 3:
        continue
        scout_title = ["","組織コンサル","医療法人の","脱飲食","転職活動の","その後の"]
    elif i == 4:
        scout_title = ["","事業企画","【非公開求人】設備工","【施工管理職／総合建設","湘南エリア","神奈川エリア","既存事業、新規事業共に加速できる","城南エリア","【施工管理職／オフィス・商業ビル","建設業出身者による","建築案件多数","土木案件多数","電気・設備案件","転職活動の","その後の"]
        continue    
    elif i == 5:
        scout_title = ["","医療法人の運営","事業企画","コストコンサル","人事企画","採用企画","人事労務採用","チーム内で","安心で","社内ITサポート業務","経理/財務","外資コンサル","都内科学系","地域密着で","転職活動の","その後の"]
        continue
    elif i == 6:
        scout_title = ["","医療という","インテリア・ファッション","×ICT","経理/財務","社内IT","バックオフィスの","Break","転職活動の","その後の"]
        continue
    elif i == 7:
        continue
        scout_title = ["","医療法人の運営マネージャー","【事業企画ポジション】上場企業／完全週休2日/異業種・事業企画","【ブロックマネージャー候補】異業界出身者多数/資格手当あり/半年間の研修でしっかりサポート","【経営企画】上場企業/大崎駅直結&リモートワークOK","経営企画・経営陣へのレポーティング","【労務】評価が明確で昇給実績もあり","転職活動の","その後の"]
    
    
    browser = webdriver.Chrome(executable_path = 'C:/Users/s-mat/Downloads/MyPandas/chromedriver.exe')
    browser.implicitly_wait(5)
    browser.get(url_login)
    time.sleep(1)
    print("ログインページに開きました")
    
    element = browser.find_element_by_id('head_hunter_email')
    element.clear()
    element.send_keys(HEAD_HUNTER[0])

    element = browser.find_element_by_id('head_hunter_password')
    element.clear()
    element.send_keys(HEAD_HUNTER[1])
    print("情報を入力しました")

    browser_from = browser.find_element_by_name('commit')
    time.sleep(1)
    browser_from.click()
    print("情報を入力してログインボタンを押しました")

    browser_from = browser.find_element_by_xpath('/html/body/header/nav/ul/li[3]/a')
    time.sleep(1)
    browser_from.click()
    print("モニタリングページへ移動しました")
    time.sleep(1)

    element = browser.find_element_by_name('received_at_start')
    element.clear()
    element.send_keys(DAY)

    element = browser.find_element_by_name('received_at_end')
    element.clear()
    element.send_keys(DAY)

    browser_from = browser.find_element_by_name('commit')
    time.sleep(1)
    browser_from.click()
    print("日付を送信")
    
    time.sleep(3)

    scout_count_all = browser.find_element_by_xpath('/html/body/div[1]/div/div[1]/div/div[2]/table[1]/tbody/tr[2]/td[1]')
    normal_count = browser.find_element_by_xpath('/html/body/div[1]/div/div[1]/div/div[2]/table[2]/tbody/tr[2]/td[1]')
    limited_count = browser.find_element_by_xpath('/html/body/div[1]/div/div[1]/div/div[2]/table[2]/tbody/tr[2]/td[4]')
    fithunter_count = browser.find_element_by_xpath('/html/body/div[1]/div/div[1]/div/div[2]/table[2]/tbody/tr[2]/td[7]')
    automatic_count = browser.find_element_by_xpath('/html/body/div[1]/div/div[1]/div/div[2]/table[2]/tbody/tr[2]/td[10]')
    remindchance_count = browser.find_element_by_xpath('/html/body/div[1]/div/div[1]/div/div[2]/table[2]/tbody/tr[2]/td[13]')
    reply_count_all = browser.find_element_by_xpath('/html/body/div[1]/div/div[1]/div/div[2]/table[1]/tbody/tr[2]/td[2]')
    
    scout_count_jidou = int(automatic_count.text) + int(remindchance_count.text)
    scout_count_nozoku = int(scout_count_all.text) - scout_count_jidou
    df_monitoring = pd.DataFrame([['コンサルタント',HEAD_HUNTER[0]],['送信全件',scout_count_all.text],['通常スカウト',normal_count.text],['一球入魂',limited_count.text],['fithunter',fithunter_count.text],['自動再送',automatic_count.text],['リマチャン',remindchance_count.text],['「再送除く」',scout_count_nozoku],['返信数',reply_count_all.text]])
    df_monitoring_count = pd.concat([df_monitoring_count,df_monitoring],join='outer',ignore_index=True)
    display(df_monitoring)
    
    browser_from = browser.find_element_by_xpath('/html/body/header/nav/ul/li[6]/a')
    browser_from.click()
    print("求職者一覧ページへ移動しました")

    element = browser.find_element_by_name('message_search_form[date_from]')
    element.clear()
    element.send_keys(DAY)

    element = browser.find_element_by_name('message_search_form[date_to]')
    element.clear()
    element.send_keys(DAY)
    print("フォームを送信")

    browser_from = browser.find_element_by_xpath('//*[@id="new_message_search_form"]/dl[3]/dd/div[1]/div[1]/ins')
    browser_from.click()
    print("受信をクリア")

    browser_from = browser.find_element_by_xpath('//*[@id="new_message_search_form"]/dl[3]/dd/div[2]/div[1]/ins')
    browser_from.click()
    print("送信をチェック")

    browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[1]/div[2]/form/dl[3]/dd/div[2]/div[5]/ins')
    browser_from.click()
    print("返信をクリア")

    time.sleep(1)
    browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[1]/div[2]/form/dl[4]/dd/div[1]/ins')
    browser_from.click()
    print("件名をチェック")
    time.sleep(1)

    for s_title in scout_title:

        browser_from = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[1]/div[2]/form/dl[4]/dd/input[1]')
        browser_from.clear()
        browser_from.send_keys(s_title)

        browser_from = browser.find_element_by_name('commit')
        time.sleep(1)
        browser_from.click()
        print("「" + s_title + "」" + "を検索しました")

        try:
            send_all = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[2]/p')
            send_all_count = re.sub(r"\D", "", send_all.text.split('全')[1])
            print(HEAD_HUNTER[0] + "は、「" + s_title + "」" + send_all_count + "件")

            df = pd.DataFrame([[HEAD_HUNTER[0],s_title,send_all_count]],columns=['コンサルタント','send_tittle','number'])
            df_count = pd.concat([df_count,df],join='outer',ignore_index=True)

        except NoSuchElementException:
            print("送信0件です")

    else:
        df = pd.DataFrame([[HEAD_HUNTER[0],"再送合計",scout_count_jidou]],columns=['コンサルタント','send_tittle','number'])
        df_count = pd.concat([df_count,df],join='outer',ignore_index=True)
        df = pd.DataFrame([[HEAD_HUNTER[0],"送信合計",scout_count_nozoku]],columns=['コンサルタント','send_tittle','number'])
        df_count = pd.concat([df_count,df],join='outer',ignore_index=True)
# Out:
# C:\Users\s-mat\AppData\Local\Temp\ipykernel_18940\204715120.py:33: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path = 'C:/Users/s-mat/Downloads/MyPandas/chromedriver.exe')
# ログインページに開きました
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18940\204715120.py in <module>
#      37     print("ログインページに開きました")
#      38
# ---> 39     element = browser.find_element_by_id('head_hunter_email')
#      40     element.clear()
#      41     element.send_keys(HEAD_HUNTER[0])
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_id'

# %%
df_count

# %%
df_monitoring_count
